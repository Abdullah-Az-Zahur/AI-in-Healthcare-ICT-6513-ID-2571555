# %% [markdown]
# # Lung Cancer CNN Demo (Colab)
# This notebook is designed for running the project directly from GitHub in Google Colab.
#
# Quick option:
# 1. Run Cell 2 only (one-click pipeline).
# 2. Upload `kaggle.json` when prompted.
#
# Manual option:
# 1. Clone repo and install dependencies.
# 2. Upload Kaggle API key (`kaggle.json`).
# 3. Run training and show saved outputs.

# %%
# One-click run for class demo (run this single cell)
REPO_URL = "https://github.com/Abdullah-Az-Zahur/AI-in-Healthcare-ICT-6513-ID-2571555.git"
PROJECT_DIR = "/content/repo/task 2 - CNN implementation"

import os
import glob
from google.colab import files

if not os.path.exists("/content/repo"):
    # !git clone $REPO_URL repo

# %cd "$PROJECT_DIR"
# !pip -q install -r requirements.txt

if not os.path.exists("/root/.kaggle/kaggle.json"):
    print("Upload kaggle.json to continue...")
    _ = files.upload()
    os.makedirs("/root/.kaggle", exist_ok=True)
    # !cp kaggle.json /root/.kaggle/kaggle.json
    # !chmod 600 /root/.kaggle/kaggle.json

# !python main.py
print("Saved models:", glob.glob("*.pth"))

# %%
# 1) Clone main repository and move into this task folder
REPO_URL = "https://github.com/Abdullah-Az-Zahur/AI-in-Healthcare-ICT-6513-ID-2571555.git"
PROJECT_DIR = "/content/repo/task 2 - CNN implementation"

# !git clone $REPO_URL repo
# %cd "$PROJECT_DIR"

# 2) Install dependencies for this specific task
# !pip -q install -r requirements.txt
print("Setup complete for task 2 - CNN implementation.")

# %%
# 3) Configure Kaggle API in Colab
from google.colab import files
import os

print("Upload your kaggle.json file now...")
_ = files.upload()

os.makedirs("/root/.kaggle", exist_ok=True)
# !cp kaggle.json /root/.kaggle/kaggle.json
# !chmod 600 /root/.kaggle/kaggle.json

print("Kaggle API configured.")

# %%
# 4) Train model
# !python main.py

# %%
# 5) Show generated model files
import glob
print(glob.glob("*.pth"))
